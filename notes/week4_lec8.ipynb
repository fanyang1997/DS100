# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
plt.style.use('seaborn-white')
plt.rc('figure', dpi=100, figsize=(7, 5))
plt.rc('font', size=12)

# %%
kdf = pd.read_csv("data/babies.data", delim_whitespace=True)
kdf.head()
# Out:
#    bwt  gestation  parity  age  height  weight  smoke
# 0  120        284       0   27      62     100      0
# 1  113        282       0   33      64     135      0
# 2  128        279       0   28      64     115      1
# 3  123        999       0   36      69     190      0
# 4  108        282       0   23      67     125      1

# %%
ax = sns.distplot(kdf.bwt, rug=False)
ax.set_xlabel("Birth weight in ounces")
ax.set_ylabel("Normalized birth weight distribution of babies");

# %%
kdf2 = pd.read_csv("data/babies.data", delim_whitespace=True)
kdf2.head()
# Out:
#    bwt  gestation  parity  age  height  weight  smoke
# 0  120        284       0   27      62     100      0
# 1  113        282       0   33      64     135      0
# 2  128        279       0   28      64     115      1
# 3  123        999       0   36      69     190      0
# 4  108        282       0   23      67     125      1

# %%
kdf2.columns
# Out:
# Index(['bwt', 'gestation', 'parity', 'age', 'height', 'weight', 'smoke'], dtype='object')

# %%
pp = pd.read_csv("data/plaplannedparenthood.csv")
pp
# Out:
#                           category number_of_procedures  \
# 0      STI/STD Testing & Treatment            4,218,149
# 1                    Contraception            2,945,059
# 2    Other Women’s Health Services            1,190,408
# 3  Cancer Screening and Prevention              682,208
# 4                Abortion Services              323,999
# 5                   Other Services               95,759
#
#   percentage_of_procedures
# 0                      45%
# 1                      31%
# 2                      13%
# 3                       7%
# 4                       3%
# 5                       1%
